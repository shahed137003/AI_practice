# %%
import os 
import object_detection

# %%
# !pip list
# Out:
# Package                      Version
# ---------------------------- --------------
# absl-py                      2.3.1
# anyio                        4.10.0
# argon2-cffi                  25.1.0
# argon2-cffi-bindings         25.1.0
# arrow                        1.3.0
# asttokens                    3.0.0
# astunparse                   1.6.3
# async-lru                    2.0.5
# attrs                        25.3.0
# babel                        2.17.0
# beautifulsoup4               4.13.5
# bleach                       6.2.0
# cachetools                   5.5.2
# certifi                      2025.8.3
# cffi                         2.0.0
# charset-normalizer           3.4.3
# colorama                     0.4.6
# comm                         0.2.3
# contextlib2                  21.6.0
# contourpy                    1.3.2
# cycler                       0.12.1
# Cython                       3.1.4
# debugpy                      1.8.17
# decorator                    5.2.1
# ...
